# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Muhamad Reizal Putra Hidayat
# - **Email:** mohreizal27@gmail.com
# - **ID Dicoding:** reizalputra

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1
# - Pertanyaan 2

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
aotizhongxin_df = pd.read_csv('./data/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
changping_df = pd.read_csv('./data/PRSA_Data_Changping_20130301-20170228.csv')
dingling_df  = pd.read_csv('./data/PRSA_Data_Dingling_20130301-20170228.csv')
dongsi_df  = pd.read_csv('./data/PRSA_Data_Dongsi_20130301-20170228.csv')
guanyuan_df = pd.read_csv('./data/PRSA_Data_Guanyuan_20130301-20170228.csv')
gucheng_df = pd.read_csv('./data/PRSA_Data_Huairou_20130301-20170228.csv')
huairou_df = pd.read_csv('./data/PRSA_Data_Huairou_20130301-20170228.csv')
nongzhanguan_df = pd.read_csv('./data/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
shunyi_df = pd.read_csv('./data/PRSA_Data_Shunyi_20130301-20170228.csv')
tiantin_df = pd.read_csv('./data/PRSA_Data_Tiantan_20130301-20170228.csv')
wanliu_df = pd.read_csv('./data/PRSA_Data_Wanliu_20130301-20170228.csv')
wanshouxigong_df = pd.read_csv('./data/PRSA_Data_Wanshouxigong_20130301-20170228.csv')

# %%
huairou_df = pd.read_csv('./data/PRSA_Data_Huairou_20130301-20170228.csv')
huairou_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %%
huairou_df[huairou_df["RAIN"] > 1]
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 458      459  2013      3   20     2   10.0   6.0   3.0  11.0   200.0  78.0
# 832      833  2013      4    4    16   71.0  82.0  18.0  43.0  1800.0  41.0
# 834      835  2013      4    4    18   72.0  81.0  17.0  46.0  1600.0  37.0
# 835      836  2013      4    4    19   56.0  70.0  14.0  41.0  1700.0  27.0
# 836      837  2013      4    4    20   64.0  71.0  13.0  41.0  1700.0  22.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 32080  32081  2016     10   27    16   25.0  31.0   2.0  29.0   700.0  31.0
# 32081  32082  2016     10   27    17   24.0  31.0   2.0  27.0   600.0  25.0
# 32082  32083  2016     10   27    18   26.0  31.0   2.0  26.0   700.0  24.0
# 32652  32653  2016     11   20    12   47.0  47.0   2.0  47.0  1500.0   2.0
# 32653  32654  2016     11   20    13   53.0  53.0   2.0  44.0  1500.0   2.0
#
# ...

# %%
guanyuan_df = pd.read_csv('./data/PRSA_Data_Guanyuan_20130301-20170228.csv')
guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %%
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
all_station_df = pd.concat(
    [aotizhongxin_df,
    changping_df,
    dingling_df,
    dongsi_df,
    guanyuan_df,
    gucheng_df,
    huairou_df,
    nongzhanguan_df,
    shunyi_df,
    tiantin_df,
    wanliu_df,
    wanshouxigong_df],
    ignore_index=True
    )

# %%
all_station_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
all_station_df.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  411722.000000  413923.000000  411274.000000
# mean       11.500000      78.611807     102.321033      15.562475
# std         6.922195      79.938434      90.623836      21.497717
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %%
all_station_df.isna().sum()
# Out:
#         No  year  month  day  hour  PM2.5  PM10  SO2  NO2  CO  O3  TEMP  PRES  \
# 0      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 1      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 2      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 3      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 4      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# ...     ..   ...    ...  ...   ...    ...   ...  ...  ...  ..  ..   ...   ...
# 420763 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420764 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420765 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420766 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420767 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
#
# ...

# %%
all_station_df[all_station_df.duplicated()]
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2      CO    O3  \
# 210384      1  2013      3    1     0    7.0   7.0  3.0   2.0   100.0  91.0
# 210385      2  2013      3    1     1    4.0   4.0  3.0   NaN   100.0  92.0
# 210386      3  2013      3    1     2    4.0   4.0  NaN   NaN   100.0  91.0
# 210387      4  2013      3    1     3    3.0   3.0  3.0   2.0     NaN   NaN
# 210388      5  2013      3    1     4    3.0   3.0  7.0   NaN   300.0  86.0
# ...       ...   ...    ...  ...   ...    ...   ...  ...   ...     ...   ...
# 245443  35060  2017      2   28    19   16.0  28.0  2.0  19.0   300.0  95.0
# 245444  35061  2017      2   28    20   21.0  34.0  4.0  24.0   500.0  80.0
# 245445  35062  2017      2   28    21   17.0  33.0  2.0  39.0   900.0  60.0
# 245446  35063  2017      2   28    22   11.0  29.0  3.0  32.0  1400.0  69.0
# 245447  35064  2017      2   28    23   11.0  20.0  2.0  27.0   400.0  77.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
all_station_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 420763    False
# 420764    False
# 420765    False
# 420766    False
# 420767    False
# Length: 420768, dtype: bool

# %%
print("Jumlah duplikasi: ", all_station_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  35064

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
